# %%
import gc
import json
import tarfile
import codecs
import sys 

index_name = "ms-marco-docs"
zipped_collection_file = "/backup/MS-MARCO/"+index_name+".tar.gz"

def collection_iterator(file_name, f_map=None):
    return collection_iterator_fn(file_name=file_name, f_map=f_map)()

def collection_iterator_fn(file_name, f_map=None):
    
    reader = codecs.getreader("ascii")
    tar = tarfile.open(file_name)

    print("[CORPORA] Openning tar file", file_name)

    members = tar.getmembers()
    
    def generator():
        for m in members:
            print("[CORPORA] Openning tar file {}".format(m.name))
            f = tar.extractfile(m)
            articles = json.load(reader(f))
            if f_map is not None:
                articles = list(map(f_map, articles))
            yield articles
            f.close()
            del f
            gc.collect()
    return generator

# %%
from nir.tokenizers import Regex, BioCleanTokenizer, BioCleanTokenizer2
import os

tk = Regex(cache_folder=os.path.join(cache_folder, "tokenizers"),
            prefix_name=index_name,
            min_word_frequency=5,
            n_process=12)

def load_queres(file):
    df = pd.read_csv("/backup/MS-MARCO/"+file, sep="\t")
    df.columns = ["id", "query"]

    queries = []
    for _,l in df.iterrows():
        queries.append({"query":str(l["query"]),
                        "id":l["id"]})
    
    return queries

def text_to_tokenize_generator():
    print("MSMARCO queries")
    queries = []
    queries.extend(map(lambda x:x["query"],load_queries("msmarco-doctrain-queries.tsv")))
    queries.extend(map(lambda x:x["query"],load_queries("msmarco-docdev-queries.tsv")))
    queries.extend(map(lambda x:x["query"],load_queries("msmarco-test2019-queries.tsv")))
    queries.extend(map(lambda x:x["query"],load_queries("msmarco-test2020-queries.tsv")))
    yield queries
    
    print("MSMARCO collection")
    yield collection_iterator(zipped_collection_file, lambda x:x["text"])


tk.fit_tokenizer_multiprocess(text_to_tokenize_generator())

tk.save_to_json()

# %%
queries
# Out:
# [{'query': '_________ justice is designed to repair the harm to victim, the community and the offender caused by the offender criminal act. question 19 options:',
#   'id': 1185868},
#  {'query': 'elegxo meaning', 'id': 1183785},
#  {'query': 'what does physical medicine do', 'id': 645590},
#  {'query': 'feeding rice cereal how many times per day', 'id': 186154},
#  {'query': 'most dependable affordable cars', 'id': 457407},
#  {'query': 'lithophile definition', 'id': 441383},
#  {'query': 'what is a flail chest', 'id': 683408},
#  {'query': 'put yourself on child support in texas', 'id': 484187},
#  {'query': 'what happens in a wrist sprain', 'id': 666321},
#  {'query': 'what are rhetorical topics', 'id': 564233},
#  {'query': 'what is considered early fall', 'id': 733739},
#  {'query': 'what causes elevated nitrate levels in aquariums', 'id': 1164798},
#  {'query': 'lyme disease symptoms mood', 'id': 443797},
#  {'query': 'what forms the epineurium', 'id': 662502},
#  {'query': 'an alpha helix is an example of which protein structure?',
#   'id': 1184679},
#  {'query': 'aggregate demand curve', 'id': 14562},
#  {'query': 'what county is ackley iowa in', 'id': 602162},
#  {'query': 'what is adiabatic?', 'id': 708236},
#  {'query': 'what is a nrr noise reduction rating mean', 'id': 693161},
#  {'query': 'fibroid symptoms after menopause', 'id': 186617},
#  {'query': 'what are the requirements for neurologist', 'id': 573027},
#  {'query': 'meaning of ..bann..', 'id': 1173772},
#  {'query': 'watts & browning engineers', 'id': 541973},
#  {'query': 'how long was jack denison dorothy dandridge married',
#   'id': 273090},
#  {'query': 'literal define', 'id': 441269},
#  {'query': 'what does lease to purchase on car mean?', 'id': 642237},
#  {'query': 'steering define', 'id': 503515},
#  {'query': 'what does fb mean on a ring', 'id': 637443},
#  {'query': 'what causes elevation in ast (sgot)', 'id': 1164796},
#  {'query': 'what is garlic used for', 'id': 749988},
#  {'query': 'definition of legal term injunctive relief', 'id': 135841},
#  {'query': 'how many seconds should check for breathing', 'id': 295446},
#  {'query': 'what does the term bar none mean', 'id': 653051},
#  {'query': 'is frida kahlo mexican', 'id': 410621},
#  {'query': 'what causes everything to taste sugary', 'id': 1164795},
#  {'query': 'what color is venus planet', 'id': 598443},
#  {'query': 'what class lever is a nutcracker', 'id': 596451},
#  {'query': 'what does the name halima mean', 'id': 651441},
#  {'query': 'meds that can cause irregular heartbeat', 'id': 452286},
#  {'query': 'how much does a ballet dancer make', 'id': 308543},
#  {'query': 'spousal roth ira contribution after age 70', 'id': 501778},
#  {'query': 'typical retirement fers', 'id': 531029},
#  {'query': 'what does the name asia mean', 'id': 651110},
#  {'query': 'infrax system', 'id': 396032},
#  {'query': 'what is a virtual interface', 'id': 705580},
#  {'query': "what ethnicity is darren criss' mom?", 'id': 658203},
#  {'query': 'how was the esperanza fire started', 'id': 387734},
#  {'query': 'what does whistling dixie mean', 'id': 655102},
#  {'query': 'how does a bump key work', 'id': 224712},
#  {'query': 'what causes exhaust hanger to fail', 'id': 1164793},
#  {'query': 'what county is fine ny in', 'id': 605902},
#  {'query': 'what can cause a metallic smell', 'id': 581014},
#  {'query': 'vde definition', 'id': 535936},
#  {'query': 'definition chemical', 'id': 130335},
#  {'query': 'difference between hep b and c', 'id': 147535},
#  {'query': 'what causes extreme swelling in just one leg?', 'id': 1164792},
#  {'query': 'what are the drugs used for moderate sedation', 'id': 569308},
#  {'query': 'what is hardie plank', 'id': 753706},
#  {'query': 'what does isf mean fluid do', 'id': 627871},
#  {'query': 'what is a affidavit of support', 'id': 673608},
#  {'query': 'syracuse minor league baseball', 'id': 510071},
#  {'query': 'current fuel price in delhi', 'id': 113839},
#  {'query': 'what causes eyelid itching and swelling', 'id': 1164791},
#  {'query': 'element al', 'id': 1183784},
#  {'query': 'what causes feelings of detachment from reality,', 'id': 1164790},
#  {'query': 'concrete walkway cost per square foot', 'id': 96740},
#  {'query': 'armistead meaning', 'id': 26666},
#  {'query': 'ross cameron age', 'id': 490046},
#  {'query': 'reasons why nuclear power is bad', 'id': 485823},
#  {'query': 'what does dealer invoice price mean', 'id': 635632},
#  {'query': 'singular noun definition for kids', 'id': 498612},
#  {'query': 'causes of back pain in female for a week', 'id': 85453},
#  {'query': 'what county is exeter nh', 'id': 605764},
#  {'query': 'what is fms medical term', 'id': 748182},
#  {'query': 'what is boot screening?', 'id': 725274},
#  {'query': 'is acre capitalized', 'id': 401461},
#  {'query': 'what does it mean when the bottom of your foot is really hot',
#   'id': 641186},
#  {'query': 'oliguric meaning', 'id': 468434},
#  {'query': 'average annual snowfall in jersey', 'id': 31086},
#  {'query': 'what is e. pluribus unum', 'id': 742160},
#  {'query': 'how much do club set bottles cost?', 'id': 305154},
#  {'query': 'what causes film creasing during folding process', 'id': 1164787},
#  {'query': 'what is a lease?', 'id': 688661},
#  {'query': 'va choice provider phone number', 'id': 535243},
#  {'query': 'how much is a pint of patron', 'id': 321187},
#  {'query': 'what all is ferric gluconate used for', 'id': 553140},
#  {'query': 'causes of swollen ankles and feet', 'id': 88585},
#  {'query': 'is levaquin an antibiotic', 'id': 416278},
#  {'query': 'what does the sphinx represent', 'id': 652801},
#  {'query': 'meaning of obtunded', 'id': 448861},
#  {'query': 'what county is marlboro, nj', 'id': 609117},
#  {'query': 'what is a health unit coordinator', 'id': 686474},
#  {'query': 'inherent legal definition', 'id': 396120},
#  {'query': 'carbs withdrawal signs and symptoms', 'id': 82631},
#  {'query': 'is turmeric curcumin', 'id': 430171},
#  {'query': 'is rosemary oil good for back pain?', 'id': 422799},
#  {'query': 'what are setbacks in zoning', 'id': 564701},
#  {'query': 'what is a cleric', 'id': 677722},
#  {'query': 'what files do dvd players read', 'id': 659630},
#  {'query': 'integrated dna technology', 'id': 396846},
#  {'query': 'what happens when waves hit a concave surface', 'id': 667478},
#  {'query': 'does dehydration cause sleep harder', 'id': 165324},
#  {'query': '(metformin what is it and what does it do?)', 'id': 118},
#  {'query': 'unconscious bias definition', 'id': 531802},
#  {'query': 'most expensive places in the world dublin', 'id': 457773},
#  {'query': 'what causes fluid in the ears?', 'id': 1164782},
#  {'query': 'what does the legal term demur mean?', 'id': 650692},
#  {'query': 'what do architectural drawings show', 'id': 622007},
#  {'query': 'salt water aquarium salinity', 'id': 492528},
#  {'query': 'prices for massages', 'id': 481431},
#  {'query': 'how many species go extinct in an average day', 'id': 296072},
#  {'query': 'what is an alias name', 'id': 711452},
#  {'query': 'what county is lawton, ok', 'id': 608452},
#  {'query': 'pluvious definition', 'id': 476121},
#  {'query': 'does restrictive lung disease cause sleep apnea', 'id': 170935},
#  {'query': 'how common is the name andrew?', 'id': 212020},
#  {'query': 'what is human trafficking', 'id': 756195},
#  {'query': 'how much is does it cost to insure a house', 'id': 321944},
#  {'query': 'irs continuing education requirements', 'id': 398567},
#  {'query': 'to_date function', 'id': 522059},
#  {'query': 'what degree  is ideal flag mount', 'id': 617436},
#  {'query': 'amnesty define', 'id': 17008},
#  {'query': 'time hawaii', 'id': 520990},
#  {'query': 'how to become a class b cdl driver', 'id': 344949},
#  {'query': 'what includes in nursing general survey', 'id': 670628},
#  {'query': 'what did the nuremberg trials do explanation', 'id': 620254},
#  {'query': 'what are mangroves', 'id': 561453},
#  {'query': 'what is an open system server', 'id': 716682},
#  {'query': 'meaning of material requisition', 'id': 448235},
#  {'query': 'what is a prostate rub', 'id': 696473},
#  {'query': 'population brigham city utah', 'id': 476888},
#  {'query': 'price clips', 'id': 480096},
#  {'query': 'team uniform color schemes', 'id': 511086},
#  {'query': 'what causes gall bladder infection', 'id': 1164777},
#  {'query': 'does vinegar help poison ivy', 'id': 173769},
#  {'query': 'is the pill nabumetone a narcotic', 'id': 427099},
#  {'query': 'symptoms of strep throat for an adult', 'id': 508811},
#  {'query': 'if i contribute to a roth ira is it taxable', 'id': 391495},
#  {'query': 'what causes hair to break', 'id': 588376},
#  {'query': 'what causes gall bladder infections?', 'id': 1164776},
#  {'query': 'meaning of a navigate', 'id': 1173770},
#  {'query': 'what does a spider bute sore look like', 'id': 630360},
#  {'query': 'is china bigger than the united states', 'id': 406188},
#  {'query': 'what degree sunburn causes blisters', 'id': 617804},
#  {'query': 'average age of nhl teams', 'id': 30619},
#  {'query': 'how much does it cost to replace a foundation of a house?',
#   'id': 316639},
#  {'query': 'what is glycohemoglobin', 'id': 751529},
#  {'query': 'redemption cast', 'id': 486399},
#  {'query': 'defense base act chubb', 'id': 116736},
#  {'query': 'what are hereditary traits', 'id': 559956},
#  {'query': 'how to freeze fresh beet greens', 'id': 360382},
#  {'query': 'what causes gout in ankles?', 'id': 1164772},
#  {'query': 'how many of methane is released by cows', 'id': 290590},
#  {'query': 'what is buprenorphine taken for?', 'id': 726424},
#  {'query': 'derivation of roe name', 'id': 1184764},
#  {'query': 'kahley meaning', 'id': 433744},
#  {'query': 'what is fascial stretch therapy', 'id': 746395},
#  {'query': 'how many days are in a school year in texas', 'id': 280775},
#  {'query': 'lasagna meaning', 'id': 437723},
#  {'query': 'weather in santorini in august', 'id': 545859},
#  {'query': 'what is eden lake', 'id': 742685},
#  {'query': 'what is a receptionist', 'id': 697504},
#  {'query': 'are poppies grown from seed or bulb', 'id': 24388},
#  {'query': 'what is abstract noun for rich', 'id': 707182},
#  {'query': 'what does tax mean', 'id': 649051},
#  {'query': 'what is inhibitors', 'id': 759231},
#  {'query': 'anthracite highest', 'id': 1183782},
#  {'query': 'on what date is the solar eclipse this year', 'id': 468728},
#  {'query': 'movie , how he invented things', 'id': 460001},
#  {'query': 'what foods to avoid if you have burning mouth syndrome',
#   'id': 661940},
#  {'query': 'how long can i stay in cambodia', 'id': 242169},
#  {'query': 'what are three branches of government', 'id': 575787},
#  {'query': 'most quoted writer in english language', 'id': 459088},
#  {'query': 'what causes headache at back of head and behind eyes',
#   'id': 1164764},
#  {'query': 'what do rabbits eat in the wild', 'id': 624575},
#  {'query': 'definition of the word conjure', 'id': 138829},
#  {'query': 'what is a mood disorder', 'id': 691516},
#  {'query': 'adjustable mortgage loans definition', 'id': 11653},
#  {'query': '8 days after conception symptoms', 'id': 1173769},
#  {'query': 'what causes heterochromia eyes and', 'id': 1164761},
#  {'query': 'what cause chest pains', 'id': 583734},
#  {'query': 'what county is macungie, pa in', 'id': 608955},
#  {'query': 'what is epidemiology pdf', 'id': 744373},
#  {'query': 'how many leadership characteristics', 'id': 287532},
#  {'query': 'inorganic nutrients definition', 'id': 396288},
#  {'query': 'what is a financier dessert', 'id': 683242},
#  {'query': 'can threadworms cause appendicitis', 'id': 1164759},
#  {'query': 'foods to avoid in gallbladder disease', 'id': 189935},
#  {'query': 'what is a mastic', 'id': 690255},
#  {'query': 'what causes white tongue coating', 'id': 593603},
#  {'query': 'masseter definition', 'id': 445857},
#  {'query': 'gas octane ratings', 'id': 193384},
#  {'query': 'what duration should you change your refrigerator water filter',
#   'id': 656174},
#  {'query': 'what causes hives and itching', 'id': 1164758},
#  {'query': 'meaning of samoset', 'id': 449132},
#  {'query': 'alcohol disinfect', 'id': 15252},
#  {'query': 'what are some of the main causes of deforestation in amazon rainforest',
#   'id': 565659},
#  {'query': 'promulgates definition', 'id': 482806},
#  {'query': 'what generation is keflex', 'id': 663380},
#  {'query': 'is waiver of subrogation on gl or property', 'id': 1174666},
#  {'query': 'how long does it take epoxy floor to cure', 'id': 252674},
#  {'query': 'waterloo war', 'id': 541895},
#  {'query': 'liters measures what', 'id': 441367},
#  {'query': 'what date is jefferson tx mardi gras', 'id': 616319},
#  {'query': 'soleil meaning', 'id': 500192},
#  {'query': 'nad / nadh definition', 'id': 5202},
#  {'query': 'what county is nyc', 'id': 610542},
#  {'query': 'what does interossei mean', 'id': 639751},
#  {'query': 'what is flight time from newark to heathrow', 'id': 747871},
#  {'query': 'what is dyeing', 'id': 741934},
#  {'query': 'is intellectual property tangible', 'id': 413103},
#  {'query': 'what causes you aortic artery to get plaque build up',
#   'id': 593717},
#  {'query': 'what causes stinging pain', 'id': 592050},
#  {'query': 'what is a good profit margin ratio', 'id': 685380},
#  {'query': 'can not enough sleep make adhd', 'id': 71865},
#  {'query': 'what is a gdb file gis', 'id': 684440},
#  {'query': 'definition of the calculus', 'id': 138729},
#  {'query': 'what does col mean for a source document', 'id': 634747},
#  {'query': 'what county is scottsboro alabama', 'id': 612478},
#  {'query': 'how did the tet offensive damage american morale?', 'id': 215545},
#  {'query': 'what conference is the u of connecticut in', 'id': 600133},
#  {'query': 'elements that exist as molecule', 'id': 1183781},
#  {'query': 'how do otters mate?', 'id': 219912},
#  {'query': 'what is blains', 'id': 724592},
#  {'query': 'what is formica', 'id': 748701},
#  {'query': 'mood definition literature', 'id': 455980},
#  {'query': 'what causes ice to be blue', 'id': 1164749},
#  {'query': 'what does it mean when your ear is popping', 'id': 641438},
#  {'query': 'what is a galena', 'id': 684298},
#  {'query': 'what is hecate', 'id': 754337},
#  {'query': 'meijer pharmacy hours of operation', 'id': 452366},
#  {'query': 'what is an allele?', 'id': 711476},
#  {'query': 'what causes squeaky sound when you turn this steering wheel with all the way?',
#   'id': 592008},
#  {'query': 'does diclofenac need prescription', 'id': 165453},
#  {'query': 'what is a platysma', 'id': 695106},
#  {'query': 'phone number for verizon wireless bill pay', 'id': 474783},
#  {'query': 'what causes inflammation arthritis', 'id': 1164746},
#  {'query': 'westcave preserve', 'id': 548479},
#  {'query': 'social security benefits working before full retirement age',
#   'id': 499812},
#  {'query': 'most dangerous sharks', 'id': 457348},
#  {'query': 'what is health benefits of coconut water', 'id': 754130},
#  {'query': 'what causes inflammation in foot', 'id': 1164745},
#  {'query': 'define and example of a grant-in-aid', 'id': 117664},
#  {'query': 'laggard meaning', 'id': 435356},
#  {'query': 'mastoid infection symptoms', 'id': 445911},
#  {'query': 'polar customer service phone number', 'id': 476407},
#  {'query': 'define fable in literature', 'id': 121365},
#  {'query': 'is ilovemakonnen ovo', 'id': 412886},
#  {'query': 't rowe price contact phone number', 'id': 510172},
#  {'query': 'what causes itching dry skin', 'id': 1164744},
#  {'query': 'towing weight definition', 'id': 523140},
#  {'query': 'age limit to drive for haul', 'id': 13315},
#  {'query': 'what elevates glucose', 'id': 657061},
#  {'query': 'what county is bethlehem, pa', 'id': 603130},
#  {'query': 'what causes lower back pain and cramping', 'id': 589631},
#  {'query': 'cancers that cause death', 'id': 81707},
#  {'query': 'what is cism team', 'id': 730829},
#  {'query': 'what causes itching during exercise', 'id': 1164743},
#  {'query': 'what did a sculpture do in ancient india', 'id': 618583},
#  {'query': 'is a crabapple tree deciduous', 'id': 399731},
#  {'query': 'what county is thermal california in', 'id': 613644},
#  {'query': 'what do heterotopias appear on imaging', 'id': 623325},
#  {'query': 'what are the two vertical muscles behind the knee', 'id': 575269},
#  {'query': 'what does the term presidential democracy mean?', 'id': 653151},
#  {'query': 'what is cost of automatic transmission service', 'id': 735199},
#  {'query': 'another term meaning executor of estate', 'id': 18970},
#  {'query': 'what are dental implants dentures', 'id': 557583},
#  {'query': 'what is cellular respiration in biology', 'id': 728984},
#  {'query': 'is apoquel safe for dogs', 'id': 403058},
#  {'query': 'what are the palatines', 'id': 572255},
#  {'query': 'what is creatinine blood test', 'id': 735744},
#  {'query': 'bear tracks cabin in pigeon forge tn', 'id': 49432},
#  {'query': 'can you propagate orchids', 'id': 79048},
#  {'query': 'how did david ruffin die', 'id': 213201},
#  {'query': 'how many miles to the gallon does a buick verano  have',
#   'id': 289167},
#  {'query': 'elements that from austenite', 'id': 1183780},
#  {'query': 'independent living for seniors in owasso ok', 'id': 395288},
#  {'query': 'what causes tire vibration', 'id': 592967},
#  {'query': "lee's sandwich vegetarian calories", 'id': 438666},
#  {'query': 'what county is wilmington, delaware in', 'id': 614703},
#  {'query': 'subq emphysema causes', 'id': 504875},
#  {'query': 'what is being', 'id': 6811},
#  {'query': 'what causes kidneys to leak protein', 'id': 1164739},
#  {'query': 'how long do you bake thin pork chops in the oven', 'id': 247230},
#  {'query': 'what causes severe low back pain when blood work and ct scan comes back normal',
#   'id': 591492},
#  {'query': 'list of gift cards sold at costco', 'id': 440856},
#  {'query': 'what are the enzymes that catalyze the synthesis of new dna called',
#   'id': 569593},
#  {'query': 'dividends vs stock price', 'id': 154289},
#  {'query': 'what are diagnostic reports', 'id': 557644},
#  {'query': 'what foods are the best to eat for leg cramps', 'id': 661106},
#  {'query': 'serpentine stone meaning', 'id': 495054},
#  {'query': 'benefit of rice water for hair', 'id': 1173767},
#  {'query': 'what is air flow meter', 'id': 709018},
#  {'query': 'the difference between absorption and assimilation', 'id': 515427},
#  {'query': 'what causes knuckle pads', 'id': 1164737},
#  {'query': 'how do you cure loss of voice', 'id': 221711},
#  {'query': 'what is akamai technologies, inc', 'id': 709162},
#  {'query': 'what county is rochester, wa', 'id': 612024},
#  {'query': 'what causes lava to erupt as pyroclasts', 'id': 1164736},
#  {'query': 'what color do the liatris come in', 'id': 597443},
#  {'query': 'what county is hagerstown in in', 'id': 606851},
#  {'query': 'meaning of lincoln', 'id': 448166},
#  {'query': 'average household income phoenix', 'id': 37504},
#  {'query': 'what is demountable partitions', 'id': 738470},
#  {'query': 'how much does a mclaren cost', 'id': 310290},
#  {'query': 'what antibiotic eye drops are prescribed after cataract surgery',
#   'id': 553949},
#  {'query': 'is there a such thing as organic seeds', 'id': 428555},
#  {'query': 'toyota sienna prices paid', 'id': 523281},
#  {'query': 'what are ukuleles', 'id': 576539},
#  {'query': 'meaning of heart', 'id': 447937},
#  {'query': 'what is an activity report', 'id': 710991},
#  {'query': 'price for neck lift', 'id': 480298},
#  {'query': 'what code is used for false positive', 'id': 596897},
#  {'query': 'what does the communicating artery in the brain do', 'id': 649867},
#  {'query': 'what is an alternative software package to microsoft publisher',
#   'id': 711556},
#  {'query': 'meaning of score', 'id': 449147},
#  {'query': 'r&d acronym definition', 'id': 484785},
#  {'query': 'how to use the callaway scoring system', 'id': 385698},
#  {'query': 'what is a siamese persian mix cat', 'id': 699911},
#  {'query': 'definition of faun', 'id': 134627},
#  {'query': 'what do neurotransmitters attach to', 'id': 624097},
#  {'query': 'weather in charleston sc in march', 'id': 543762},
#  {'query': 'other hot flashes causes', 'id': 470449},
#  {'query': 'symptoms of pyelonephritis in adults', 'id': 508527},
#  {'query': 'sestina definition', 'id': 495126},
#  {'query': 'what is duoderm used for', 'id': 741772},
#  {'query': 'is it safe for dogs to eat bananas', 'id': 414496},
#  {'query': 'time for scab to fall off', 'id': 520945},
#  {'query': 'what causes effusion/hemarthrosis', 'id': 587473},
#  {'query': 'cost for surrogate', 'id': 101453},
#  {'query': 'what is antifa mean', 'id': 718690},
#  {'query': 'ordinate axis definition', 'id': 469757},
#  {'query': 'uneven chest color', 'id': 532152},
#  {'query': 'define fi$cal', 'id': 121474},
#  {'query': 'is bait and switch illegal', 'id': 403810},
#  {'query': 'what is cowardin classification system', 'id': 735486},
#  {'query': 'the cells of the immune system include four types of what',
#   'id': 514688},
#  {'query': "how do cats feel other cat's heart beats?", 'id': 216639},
#  {'query': 'what does cetirizine hydrochloride do', 'id': 634235},
#  {'query': 'what area is la metro', 'id': 577404},
#  {'query': 'what is a signature medallion?', 'id': 699971},
#  {'query': 'manheim index definition', 'id': 445089},
#  {'query': 'what is ceo', 'id': 729120},
#  {'query': 'what causes liver and spleen swelling', 'id': 1164725},
#  {'query': 'what causes a scar?', 'id': 584878},
#  {'query': 'what do people use gold for?', 'id': 624360},
#  {'query': 'is dwi a traffic violation', 'id': 408938},
#  {'query': 'distance from las vegas to hoover dam', 'id': 153580},
#  {'query': 'replacing a deck cost', 'id': 487682},
#  {'query': 'what causes liver enzymes to go up', 'id': 1164724},
#  {'query': 'what county is roy wa in', 'id': 612170},
#  {'query': 'how to raise crickets', 'id': 374612},
#  {'query': 'is udc aba accredited', 'id': 430318},
#  {'query': 'what did walt disney die', 'id': 620568},
#  {'query': 'what harvoni', 'id': 667985},
#  {'query': 'what county in florida is destin located', 'id': 601987},
#  {'query': 'how many calories are in air popped popcorn', 'id': 276042},
#  {'query': 'what is icc', 'id': 757003},
#  {'query': 'ptcb exam score to pass', 'id': 483746},
#  {'query': 'how much pay riding coach', 'id': 325993},
#  {'query': 'what is cubicin antibiotic for', 'id': 736493},
#  {'query': 'what county is brighton co', 'id': 603520},
#  {'query': 'what drugs are used for conscious sedation', 'id': 656030},
#  {'query': 'what causes liver enzymes to go up?', 'id': 1164722},
#  {'query': 'what does chimes mean', 'id': 634365},
#  {'query': 'what causes loss of hair in women', 'id': 1164721},
#  {'query': 'weather in granite falls, wa', 'id': 544357},
#  {'query': 'what does usb cord do', 'id': 654573},
#  {'query': 'what color is march stone', 'id': 598046},
#  {'query': 'types of polynomial with definition', 'id': 529320},
#  {'query': 'how many miles is yosemite from san jose california',
#   'id': 289051},
#  {'query': 'how often to change porsche boxster oil', 'id': 332622},
#  {'query': 'how long to simmer chicken breast strips for soup', 'id': 272115},
#  {'query': 'what are thebenifits of clove', 'id': 575693},
#  {'query': 'should you rinse after mouthwash', 'id': 497067},
#  {'query': 'what company owns bosch tools', 'id': 599617},
#  {'query': 'what is a spark plug electrode', 'id': 700838},
#  {'query': 'what is gobo lighting', 'id': 751663},
#  {'query': 'salaries of illinois state legislators', 'id': 491271},
#  {'query': 'what county is silver spring in', 'id': 612757},
#  {'query': 'what is an emulsion', 'id': 713518},
#  {'query': 'what does mosquito squad spray', 'id': 643669},
#  {'query': 'what is a cloze test', 'id': 677853},
#  {'query': 'meaning of the name louvenia', 'id': 449951},
#  {'query': 'what comes out of an eye when you cry', 'id': 599225},
#  {'query': 'what does no provision mean?', 'id': 644299},
#  {'query': 'what is an airplane ride like?', 'id': 711391},
#  {'query': 'what county is st paul, indiana', 'id': 613131},
#  {'query': 'what causes men to leak urine in old age', 'id': 1164717},
#  {'query': 'best type of sand to level before turfing', 'id': 52216},
#  {'query': 'deloitte federal consultant salary', 'id': 140670},
#  {'query': 'what does a nuclear stress test show', 'id': 629699},
#  {'query': 'what does a restaurant concept mean', 'id': 630158},
#  {'query': 'what does physical education promote?', 'id': 645588},
#  {'query': 'definition of caught', 'id': 133098},
#  {'query': 'chris tomlin daughter', 'id': 2500},
#  {'query': "coal miner's daughter cast", 'id': 93889},
#  {'query': "does bj's accept food stamps", 'id': 163844},
#  {'query': 'crevice define', 'id': 112716},
#  {'query': 'what does laches mean in legal terms', 'id': 642081},
#  {'query': 'what county is yucaipa california in', 'id': 614942},
#  {'query': 'what is a summary synthesis', 'id': 702173},
#  {'query': 'is a bachelors a graduate program?', 'id': 399407},
#  {'query': 'what causes enlarged liver', 'id': 587547},
#  {'query': 'important names in the civil rights movement', 'id': 393087},
#  {'query': 'what county is wallace idaho in', 'id': 614226},
#  {'query': 'what does very insightful mean', 'id': 654757},
#  {'query': 'what is crackling bread', 'id': 735646},
#  {'query': 'meaning of abbreviation poc', 'id': 1173765},
#  {'query': 'what is a pediatric doctor', 'id': 694128},
#  {'query': 'new retail definition', 'id': 463892},
#  {'query': 'can unopened lantus insulin be stored at room temperature?',
#   'id': 1164713},
#  {'query': 'what does the name evelyn mean', 'id': 650899},
#  {'query': 'what is cvs software', 'id': 736973},
#  {'query': 'what is a gri', 'id': 685854},
#  {'query': 'inspected definition', 'id': 396424},
#  {'query': 'what causes mouth blisters inside', 'id': 1164712},
#  {'query': 'the kansas city star subscription', 'id': 516558},
#  {'query': 'stripe how many days before payment', 'id': 504412},
#  {'query': 'what are foam play mats made of', 'id': 558936},
#  {'query': 'number swipe puzzle grid', 'id': 467090},
#  {'query': 'what is ecg for?', 'id': 742414},
#  {'query': 'what causes muscle low stamina', 'id': 1164711},
#  {'query': 'lymphoma start symptoms', 'id': 443892},
#  {'query': 'types of benign brain tumors', 'id': 526495},
#  {'query': 'what does civil liberties protect', 'id': 634512},
#  {'query': 'labor cost to install tile shower', 'id': 435183},
#  {'query': 'what is a disease that affects the legs', 'id': 681529},
#  {'query': 'is it legal for my landlord to enter my apartment without my permission',
#   'id': 413930},
#  {'query': 'slavery history definition', 'id': 499265},
#  {'query': 'what is a jaguars predator', 'id': 687733},
#  {'query': 'what causes nausea and hot flashes', 'id': 1164709},
#  {'query': 'http definition computer', 'id': 389184},
#  {'query': 'what is dmdd', 'id': 740464},
#  {'query': 'most products are in decline stage of product lifestyle',
#   'id': 459067},
#  {'query': 'london time india time', 'id': 441889},
#  {'query': 'definition of resource management', 'id': 137796},
#  {'query': 'what causes nausea while eating', 'id': 1164708},
#  {'query': 'weather in punta cana in nov', 'id': 545663},
#  {'query': 'what is celluclay', 'id': 728967},
#  {'query': 'what is a home study done by child lawyer', 'id': 686980},
#  {'query': 'most favorite women to win wimbledon', 'id': 457962},
#  {'query': 'what ear waxing', 'id': 656232},
#  {'query': 'convert meters to kilometers ratio', 'id': 98709},
#  {'query': 'what functional group is cyclohexene', 'id': 662874},
#  {'query': 'average commute time in longmont, co', 'id': 31928},
#  {'query': 'what classes in college do i take for sports medicine',
#   'id': 596601},
#  {'query': 'triton benefits', 'id': 524839},
#  {'query': 'what are side effects of melatonin pills', 'id': 564795},
#  {'query': 'can va compensation be suspended if incarcerated?', 'id': 1164706},
#  {'query': 'what hogwarts house was newt scamander', 'id': 669148},
#  {'query': 'explain why some economists are against a target of zero inflation',
#   'id': 184048},
#  {'query': 'is a rotisserie chicken healthy', 'id': 400840},
#  {'query': 'what is author royalty kindle unlimited', 'id': 721061},
#  {'query': 'what can you use to wear baby in water', 'id': 582984},
#  {'query': 'what is incisura', 'id': 758492},
#  {'query': 'most popular creole dish', 'id': 458594},
#  {'query': 'facts on why alcohol should be banned', 'id': 184674},
#  {'query': 'what is charge of the goddess', 'id': 729613},
#  {'query': 'what causes nighttime leg c', 'id': 1164705},
#  {'query': 'what is feldspar used for', 'id': 746789},
#  {'query': 'what can cause tooth pain', 'id': 581533},
#  {'query': 'institute for physician wellness cme', 'id': 396563},
#  {'query': 'what does wifi hotspot mean', 'id': 655160},
#  {'query': 'in what country can you find the most volcanoes', 'id': 393874},
#  {'query': 'what causes non alcoholic fatty liver', 'id': 1164704},
#  {'query': 'define heritage culture', 'id': 122232},
#  {'query': 'how do you play oklahoma gin', 'id': 223385},
#  {'query': 'what is fennel seed?', 'id': 746880},
#  {'query': 'meaning of acquitted', 'id': 1173764},
#  {'query': 'what is a lady bird deed texas', 'id': 688363},
#  {'query': 'is there a natural muscle relaxer', 'id': 428365},
#  {'query': 'what causes occasional black stools', 'id': 1164703},
#  {'query': 'what happened when alexander the great died', 'id': 665391},
#  {'query': 'what does medical abbreviation ams stand for', 'id': 643162},
#  {'query': 'what genre is scarface', 'id': 663605},
#  {'query': 'what is health advocate', 'id': 754126},
#  {'query': 'what is cpap for?', 'id': 735510},
#  {'query': 'origin and meaning of the name cassandra', 'id': 469986},
#  {'query': 'what colour is pottery', 'id': 599114},
#  {'query': 'what are the modern methods presidents use to influence the policy making process',
#   'id': 571673},
#  {'query': 'what county is wainscott ny in', 'id': 614202},
#  {'query': 'what does rdw mean in a blood test result', 'id': 646727},
#  {'query': 'what county is mikado mi in', 'id': 609486},
#  {'query': 'the ubermensch definition', 'id': 519297},
#  {'query': 'how many weeks is a term baby', 'id': 299873},
#  {'query': 'what are human rights', 'id': 560136},
#  {'query': 'what is esplost', 'id': 744886},
#  {'query': 'united technologies stock price', 'id': 532472},
#  {'query': 'average weight for teen', 'id': 47283},
#  {'query': 'medications that cause respiratory depression', 'id': 452108},
#  {'query': 'what are the layers of the atmosphere?', 'id': 570962},
#  {'query': 'longitudinal axis definition', 'id': 442909},
#  {'query': 'what causes condensation on double glazing windows', 'id': 586715},
#  {'query': 'urine chemical screening definition', 'id': 533264},
#  {'query': 'most desired watches', 'id': 457416},
#  {'query': 'define majority party leader', 'id': 123612},
#  {'query': 'meloxicam is for what', 'id': 452484},
#  {'query': 'what is hata', 'id': 753808},
#  {'query': 'netops definition', 'id': 463521},
#  {'query': 'how big is the moon', 'id': 209441},
#  {'query': 'star wars was the name given to which reagan effort?',
#   'id': 502658},
#  {'query': 'definition of extrinsic motivation', 'id': 134574},
#  {'query': 'what are the risks associated with the use of nuclear energy',
#   'id': 573198},
#  {'query': 'synonym for occur', 'id': 509581},
#  {'query': 'foods that increase thinning of blood', 'id': 189618},
#  {'query': 'what causes a person to get so sleepy after eating', 'id': 584788},
#  {'query': 'how long is a flight from miami, fl to seoul, south korea?',
#   'id': 262345},
#  {'query': 'what does grudges mean', 'id': 638530},
#  {'query': 'what causes organ to become enlarged', 'id': 1164695},
#  {'query': 'megan- name meaning- what does my name mean', 'id': 5048},
#  {'query': 'what is a travelers cheque', 'id': 704144},
#  {'query': 'payment due date meaning', 'id': 472484},
#  {'query': 'what is cannon fodder', 'id': 727428},
#  {'query': 'what is considered low for blood pressure', 'id': 733932},
#  {'query': 'what does ./path means', 'id': 627573},
#  {'query': 'how many cities in the us?', 'id': 279610},
#  {'query': 'how much are standard braces', 'id': 302360},
#  {'query': 'different versions of windows server', 'id': 151130},
#  {'query': 'what are the seven common rock forming minerals', 'id': 573413},
#  {'query': 'what causes pain in my chest when i cough', 'id': 1164692},
#  {'query': 'what can cause elevated troponin levels', 'id': 581208},
#  {'query': 'hof  meaning in german', 'id': 204038},
#  {'query': 'how far is manchester connecticut to nyc', 'id': 231633},
#  {'query': 'is it hard to get a jewelry store credit card', 'id': 413786},
#  {'query': 'what is a trireme', 'id': 704275},
#  {'query': 'is the legal  age for betting in n.y.', 'id': 426690},
#  {'query': 'how long to reach steady state of drug?', 'id': 271809},
#  {'query': 'what is difference between p value and confidence interval',
#   'id': 739506},
#  {'query': 'what causes pain in the legs?', 'id': 1164689},
#  {'query': 'what component of blood contains antibodies', 'id': 599730},
#  {'query': 'meanings of polish surnames', 'id': 450662},
#  {'query': 'what age do girls get periods', 'id': 550740},
#  {'query': 'what are the four main components of the forebrain', 'id': 569982},
#  {'query': 'what does a telemetry receiver do', 'id': 630528},
#  {'query': 'what causes heavy flem in the throat', 'id': 588585},
#  {'query': 'roy orbison how did he die', 'id': 490535},
#  {'query': 'how long can instagram videos go', 'id': 242206},
#  {'query': 'what county is bon aqua,tn', 'id': 603316},
#  {'query': 'did l ron hubbard practice black magic', 'id': 144366},
#  {'query': 'what does the mucus plug mean in a pregnant person', 'id': 650883},
#  {'query': 'can water in the ear  cause a headache', 'id': 75480},
#  {'query': 'what are tire load range', 'id': 575981},
#  {'query': 'what is havrix vaccine', 'id': 753821},
#  {'query': 'what county is upland in in', 'id': 613974},
#  {'query': 'synonyms and antonyms of doze', 'id': 509867},
#  {'query': 'how long does a usual mlb baseball game last?', 'id': 250372},
#  {'query': 'what causes pelvic prolapse', 'id': 1164686},
#  {'query': 'how did temperance movement lead to prohibition', 'id': 214743},
#  {'query': 'epinephrine effects what cells', 'id': 181093},
#  {'query': 'is marijuana legal in france', 'id': 417336},
#  {'query': 'what is crest disease', 'id': 735878},
#  {'query': 'what causes pleural plaques in both lungs', 'id': 1164685},
#  {'query': 'estimated cost of a home sprinkler system', 'id': 181705},
#  {'query': 'what does pacs stand for in radiology', 'id': 645068},
#  {'query': 'osha competent person definition', 'id': 470311},
#  {'query': 'what is apocalyptic language', 'id': 719003},
#  {'query': 'how do i get cigarette smell out of a car', 'id': 218252},
#  {'query': 'what age do dogs get vaccine', 'id': 550729},
#  {'query': 'what causes potholes in gravel driveway', 'id': 1164684},
#  {'query': 'what county is milroy pa', 'id': 609542},
#  {'query': 'pop art art definition', 'id': 476796},
#  {'query': 'did hillary give russia uranium', 'id': 144059},
#  {'query': 'how many units per ml insulin', 'id': 299131},
#  {'query': 'repair cost for vinyl flooring per square foot', 'id': 487595},
#  {'query': 'uranus conjunct saturn transit', 'id': 533133},
#  {'query': 'what is array out of bound exception in java', 'id': 719805},
#  {'query': 'what do you do for guest services', 'id': 626425},
#  {'query': 'what causes a fever and rash on babies', 'id': 584552},
#  {'query': 'diet to get rid of food allergies', 'id': 1184678},
#  {'query': 'what is allocation accounting book', 'id': 709635},
#  {'query': 'is skype best for business', 'id': 423912},
#  {'query': 'what is hmc code', 'id': 755239},
#  {'query': 'what happens when you stop smoking and start vaping',
#   'id': 667780},
#  {'query': 'what causes pseudarthrosis', 'id': 1164682},
#  {'query': 'how many calories should the average man eat', 'id': 278124},
#  {'query': 'common side effects of lexapro', 'id': 95746},
#  {'query': 'is hydrogen abundant on earth', 'id': 412652},
#  {'query': 'what is a shell company', 'id': 699723},
#  {'query': 'what causes pulsing in your eye?', 'id': 1164680},
#  {'query': 'can a blood thinner cause fluid to collect in the lungs?',
#   'id': 61922},
#  {'query': 'marginal cost of capital explained', 'id': 445336},
#  {'query': 'is glaucoma inherited', 'id': 411178},
#  {'query': 'effects of hydrogen combustion', 'id': 178738},
#  {'query': 'tell me symptoms of mesothelioma', 'id': 511462},
#  {'query': 'what are intranets', 'id': 560526},
#  {'query': 'what is challenging?.', 'id': 729517},
#  {'query': 'what does diocese mean', 'id': 635977},
#  {'query': 'is the liberty bell on display a replica?', 'id': 426703},
#  {'query': 'citi costco anywhere card benefits', 'id': 92682},
#  {'query': 'how much does a adjunct professor get paid', 'id': 308455},
#  {'query': 'what bacteria produce exotoxin', 'id': 578221},
#  {'query': 'can you dye polyester dress lighter color', 'id': 77087},
#  {'query': 'what is droning', 'id': 741380},
#  {'query': 'is parsley nutritious', 'id': 420442},
#  {'query': 'the first asylum was founded in quizlet', 'id': 516030},
#  {'query': 'what age to start adhd meds', 'id': 551947},
#  {'query': 'how many sentences in a paragraph apa', 'id': 295557},
#  {'query': 'what county in elmhurst, il', 'id': 601980},
#  {'query': 'how long does it take after interview to know if citizenship is granted',
#   'id': 252470},
#  {'query': 'how do nursing homes get paid', 'id': 219871},
#  {'query': 'what causes water heater to overheat', 'id': 593451},
#  {'query': 'how many sizes do aviator sunglasses come in', 'id': 295878},
#  {'query': 'can williams syndrome be detected', 'id': 1164673},
#  {'query': 'what does the name alitza mean', 'id': 651052},
#  {'query': 'different types of working gloves', 'id': 151098},
#  {'query': 'what is a valley?', 'id': 705100},
#  {'query': 'what is access recovery charge centurylink', 'id': 707323},
#  {'query': 'south easton mass area code', 'id': 500781},
#  {'query': 'what county is belmont ca', 'id': 603030},
#  {'query': "what causes reye's syndrome in children", 'id': 1164672},
#  {'query': 'what are the major characteristics of the dermis', 'id': 571330},
#  {'query': 'is liquid asphalt hazmat?', 'id': 416509},
#  {'query': 'types of gastric bypass pouch', 'id': 527888},
#  {'query': 'elvis was born in what state?', 'id': 1183774},
#  {'query': 'what causes ringing in the ears home treatment', 'id': 1164671},
#  {'query': 'largest fanuc robot', 'id': 436437},
#  {'query': 'what does ist mean', 'id': 639976},
#  {'query': 'organizational theory definition', 'id': 469923},
#  {'query': 'the general insurance quote number', 'id': 516199},
#  {'query': 'how does negative feedback control heart rate', 'id': 227004},
#  {'query': 'what industry is remodeling and roofing in?', 'id': 670857},
#  {'query': 'what does the name aparicio mean', 'id': 651086},
#  {'query': 'lithroscopy definition', 'id': 441386},
#  {'query': 'what is a computer wireshark', 'id': 678684},
#  {'query': 'causes of loose foul stools', 'id': 87278},
#  {'query': 'difference between full and widescreen', 'id': 147363},
#  {'query': 'guide to becoming an anesthesiologist', 'id': 197586},
#  {'query': 'what can i do with a degree in exercise science', 'id': 581917},
#  {'query': 'number of days in patient for a coronary bypass', 'id': 466532},
#  {'query': 'dead body in dream meaning', 'id': 115986},
#  {'query': 'can wind power be used in canada', 'id': 1164669},
#  {'query': 'what causes eyes to pop out', 'id': 587773},
#  {'query': 'what county is halethorpe, md', 'id': 606868},
#  {'query': 'what county is kansas city mo in', 'id': 607886},
#  {'query': 'what is a quantum dot', 'id': 697001},
#  {'query': 'weather in st. croix', 'id': 546075},
#  {'query': 'what is considered a rotator cuff', 'id': 733482},
#  {'query': 'what causes rotten egg smell inside a house', 'id': 1164667},
#  {'query': 'what is crystalline', 'id': 736314},
#  {'query': 'how many ounces in a bottle of water', 'id': 290973},
#  {'query': 'what does pineapple tattoo symbolize', 'id': 645657},
#  {'query': 'is a pap smear necessary during pregnancy', 'id': 400551},
#  {'query': 'types of validity assessment', 'id': 530355},
#  {'query': 'what does consolidate debts mean', 'id': 634990},
#  {'query': 'longest rivers in japan', 'id': 442662},
#  {'query': 'what is a system tray?', 'id': 702662},
#  {'query': 'types of tyrosine kinase', 'id': 530301},
#  {'query': 'largest byte size', 'id': 436036},
#  {'query': 's scale model railroad definition', 'id': 490937},
#  {'query': 'what do tick bites look like on human skin', 'id': 625624},
#  {'query': "beck's theory", 'id': 49498},
#  {'query': 'how many leave days earned in a month for navy', 'id': 287540},
#  {'query': 'ingredients for amazing ribs pork rub', 'id': 396072},
#  {'query': 'what is a civil offense', 'id': 677572},
#  {'query': 'what causes tender very itchy scalp', 'id': 592475},
#  {'query': 'what is a facial skin firming agent', 'id': 682758},
#  {'query': 'what happens to a current in a circuit if the resistance is increased',
#   'id': 666453},
#  {'query': 'average salary counselor', 'id': 41844},
#  {'query': 'town of mountain wi', 'id': 523181},
#  {'query': 'types of punctuation marks', 'id': 529456},
#  {'query': 'what county is trinidad co in', 'id': 613823},
#  {'query': 'what is in a quiche', 'id': 757882},
#  {'query': 'did rene angelil have a gambling problem', 'id': 144903},
#  {'query': '5 ft 6 inches in cm', 'id': 1480},
#  {'query': 'what do mites eat', 'id': 623981},
#  {'query': 'how to use jetblue credit', 'id': 385318},
#  {'query': 'what is arroz con pollo', 'id': 719836},
#  {'query': 'what is a prefect', 'id': 695822},
#  {'query': 'phone number for booking customer service', 'id': 474542},
#  {'query': 'what causes slab sweating', 'id': 1164661},
#  {'query': 'define one gigabyte', 'id': 124727},
#  {'query': 'how long do.yorkies live', 'id': 248762},
#  {'query': 'ely police station phone number', 'id': 1183773},
#  {'query': 'what causes slipped disk in dogs neck', 'id': 1164660},
#  {'query': 'harvard university teachers salary', 'id': 198783},
#  {'query': 'what is a hygrometer', 'id': 687387},
#  {'query': 'what does the name raiden mean', 'id': 651899},
#  {'query': 'time to charge capacitor in a flashlight', 'id': 521321},
#  {'query': 'is julianne hough married', 'id': 415237},
#  {'query': 'what causes some beaches to be white', 'id': 1164659},
#  {'query': 'meaning of the name jerubbaal', 'id': 449828},
#  {'query': 'what creates an agency', 'id': 615290},
#  {'query': 'largest global car companies', 'id': 436538},
#  {'query': 'what is cdr military', 'id': 728788},
#  {'query': 'what causes someone to get a shaky hand', 'id': 1164658},
#  {'query': 'what does the word usury mean', 'id': 653717},
#  {'query': 'liquid calcium magnesium citrate with vitamin d3', 'id': 440476},
#  {'query': 'causes of hypoxia in adults', 'id': 86935},
#  {'query': 'was/were established to settle disputes between the states.',
#   'id': 541311},
#  {'query': 'otc for allergic rhinitis', 'id': 470424},
#  {'query': 'madelung disease symptoms', 'id': 444313},
#  {'query': 'how dangerous is a hippo', 'id': 212283},
#  {'query': 'meaning of ade', 'id': 1173760},
#  {'query': 'what causes someone to have stinky belches', 'id': 1164657},
#  {'query': 'monounsaturated definition biology', 'id': 455779},
#  {'query': 'mandibular fossa definition', 'id': 445059},
#  {'query': 'how long does group policy update take', 'id': 251954},
#  {'query': 'fastest growing bonsai trees', 'id': 185343},
#  {'query': 'moniker synonym', 'id': 455680},
#  {'query': 'what is a nuc hive', 'id': 693172},
#  {'query': 'phone number for charbroil grills', 'id': 474555},
#  {'query': 'price per cubic foot of mulch', 'id': 481084},
#  {'query': 'must pay employee within certain amount of time after discharge',
#   'id': 460717},
#  {'query': 'what does no fear mean', 'id': 644283},
#  {'query': 'what are the virulence factors of anthrax?', 'id': 575556},
#  {'query': 'does nexgard cause seizures', 'id': 169588},
#  {'query': 'what is acupuncture', 'id': 707885},
#  {'query': 'mad dog liquor cost', 'id': 444278},
#  {'query': 'what is hydrocephalus.', 'id': 756426},
#  {'query': 'what is a lanfill', 'id': 688424},
#  {'query': 'define idiosyncratic', 'id': 122535},
#  {'query': 'what causes st depression on ekg', 'id': 1164653},
#  {'query': 'taryn meaning of name', 'id': 510589},
#  {'query': 'medication for gum disease', 'id': 451752},
#  {'query': 'what class is baclofen', 'id': 596408},
#  {'query': 'difference between us senator and congressman', 'id': 149078},
#  {'query': 'what causes stock prices to drop', 'id': 1164652},
#  {'query': 'what color is pepperdust', 'id': 598156},
#  {'query': 'what foods kill candida', 'id': 661783},
#  {'query': 'common causes of foot drop', 'id': 95447},
#  {'query': 'a middleman is a person who', 'id': 9325},
#  {'query': 'informal leadership', 'id': 395923},
#  {'query': 'what are mandalorians', 'id': 561444},
#  {'query': 'what county is southern pines in?', 'id': 612935},
#  {'query': 'is cipro and zyvox related', 'id': 406419},
#  {'query': 'what is cath lab short for', 'id': 728301},
#  {'query': 'was jeff goldblum in death wish the movie?', 'id': 540215},
#  {'query': 'embeda er side effects', 'id': 1183772},
#  {'query': 'hertz customer service salary', 'id': 201517},
#  {'query': 'is malaria caused by a fungus', 'id': 417107},
#  {'query': 'cost of attendance suny albany', 'id': 102598},
#  {'query': 'what does long term care mean', 'id': 642578},
#  {'query': 'what cause pain in left side back', 'id': 583908},
#  {'query': 'serotonin syndrome types of medication', 'id': 495040},
#  {'query': 'is clostridium tetani aerobic', 'id': 406563},
#  {'query': 'respiration is controlled by which part of the brain',
#   'id': 488378},
#  {'query': 'what is a professional degree', 'id': 696239},
#  {'query': 'what causes tomato dry rot in tomatoes', 'id': 593020},
#  {'query': 'how many people attended woodstock', 'id': 291961},
#  {'query': 'how to use footnotes in a paper', 'id': 385217},
#  {'query': 'what is a hangar', 'id': 686298},
#  {'query': 'nitrogen monoxide', 'id': 464672},
#  {'query': 'is hepatocellular diseases of the liver cancer', 'id': 412152},
#  {'query': 'mold exposure symptoms does it cause coughing', 'id': 455461},
#  {'query': 'what are .gz files', 'id': 554333},
#  {'query': 'can you use peer reviewed article references', 'id': 80770},
#  {'query': 'what causes tears in the eyes', 'id': 1164643},
#  {'query': 'how many spoons of sugar in tonic water', 'id': 296191},
#  {'query': 'what is codepen', 'id': 731872},
#  {'query': 'what big ceo died of cancer recently', 'id': 578831},
#  {'query': 'is spasmodic dysphonia hereditary', 'id': 424321},
#  {'query': 'biggest horses in the world', 'id': 53168},
#  {'query': 'is water finite?', 'id': 1174665},
#  {'query': 'translation price per word', 'id': 524085},
#  {'query': 'what all is lyrica used for', 'id': 553144},
#  {'query': 'what causes the actin filaments to slide past the myosin filaments?',
#   'id': 1164641},
#  {'query': 'what are tears of joy', 'id': 566801},
#  {'query': 'what are sunspots', 'id': 566453},
#  {'query': 'neurologists in rapid city sd', 'id': 463639},
#  {'query': 'how to find the total manufacturing cost', 'id': 359466},
#  {'query': 'walrus pup', 'id': 539114},
#  {'query': 'can you cure a tooth root abscess with just antibiotics',
#   'id': 1164640},
#  {'query': 'what causes swollen hurting ankle and foot', 'id': 592382},
#  {'query': 'is yahoo mail shutting down?', 'id': 431734},
#  {'query': 'homozygous recessive', 'id': 204986},
#  {'query': 'what is business process management', 'id': 726567},
#  {'query': 'what does disbursed amount mean', 'id': 636008},
#  {'query': 'what episode did the hound die in', 'id': 657622},
#  {'query': 'most majors won in tennis', 'id': 458297},
#  {'query': 'ashland ohio population', 'id': 27318},
#  {'query': 't-bone steak meaning', 'id': 510177},
#  {'query': 'meaning of aiden name', 'id': 447182},
#  {'query': 'what is a phrasal compound?', 'id': 694693},
#  {'query': 'how much does a prius traction battery cost', 'id': 311022},
#  {'query': 'international definition of a foot', 'id': 397231},
#  {'query': 'icd code non healing surgical wound', 'id': 390703},
#  {'query': 'average pay for a title company closer', 'id': 39772},
#  {'query': 'what does exclusionary rule mean for law enforcement',
#   'id': 637221},
#  {'query': 'what is hertz corporation', 'id': 754782},
#  {'query': 'how many weeks are there in a month', 'id': 299710},
#  {'query': 'waht is the main food energy molecule for all cells in the body',
#   'id': 538815},
#  {'query': 'what are causes of inflammation or infections in the lung',
#   'id': 556229},
#  {'query': 'what county is des moines, wa in', 'id': 605097},
#  {'query': 'what happens if the blood clot falls out', 'id': 665921},
#  {'query': 'definition of inverse', 'id': 135638},
#  {'query': 'how many americans suffer with social anxiety', 'id': 274715},
#  {'query': 'identify what pulse oximetry is meassuring', 'id': 391046},
#  {'query': 'task allocation definition', 'id': 510594},
#  {'query': 'what is a pro hormone', 'id': 696116},
#  {'query': 'oxygen is used by body cells in aerobic respiration',
#   'id': 471015},
#  {'query': 'false statement definition', 'id': 184814},
#  {'query': 'define capillaries', 'id': 118711},
#  {'query': 'symptoms of a dry cough', 'id': 506800},
#  {'query': 'what channel is nbc in atlanta', 'id': 594637},
#  {'query': 'what is imprinted concrete driveways', 'id': 757779},
#  {'query': 'how to sew a baby rag quilt', 'id': 379967},
#  {'query': 'what does enumeration date mean when referring to npi',
#   'id': 636936},
#  {'query': 'what benefits can knowledge management give a company',
#   'id': 578763},
#  {'query': 'what does harm mean', 'id': 638680},
#  {'query': 'what district is cilegon in?', 'id': 621569},
#  {'query': 'how long do i have to wait to pull the basis out of my roth',
#   'id': 245709},
#  {'query': 'list of root vegetables', 'id': 441029},
#  {'query': 'what happened to the man who shot kris kyle', 'id': 665329},
#  {'query': 'what does bearer stand for', 'id': 632970},
#  {'query': 'relevant range definition accounting', 'id': 487135},
#  {'query': 'what is an orthopedic evaluation?', 'id': 716892},
#  {'query': 'treatment of scar and stretch mark research', 'id': 524440},
#  {'query': 'can one gas displace another gas', 'id': 72014},
#  {'query': 'what causes the skin above the eyelid to droop', 'id': 1164629},
#  {'query': 'napa valley average monthly temperature', 'id': 462271},
#  {'query': 'what is a compression sleeve used for', 'id': 678624},
#  {'query': 'define fasciitis', 'id': 121415},
#  {'query': 'is generic cialis available with prescription', 'id': 410984},
#  {'query': 'calories in whole grain couscous', 'id': 61151},
#  {'query': 'what causes the tiny bump on tip of tongue', 'id': 1164628},
#  {'query': 'myron meaning of name', 'id': 461000},
#  {'query': 'is a sham a comforter', 'id': 400898},
#  {'query': 'what is in darvocet', 'id': 758041},
#  {'query': 'how to become a u.s. marshal', 'id': 345474},
#  {'query': 'is putlocker.ch down', 'id': 421997},
#  {'query': 'what causes the transmission fluid to aerate', 'id': 1164627},
#  {'query': 'what counts as formula on excel', 'id': 601819},
#  {'query': 'speech or language impairment definition', 'id': 501248},
#  {'query': 'what is derm surgery', 'id': 738720},
#  {'query': 'explain what amniocentesis is', 'id': 2965},
#  {'query': 'phone number for canon printers', 'id': 474551},
#  {'query': 'standard size of indian wc', 'id': 502499},
#  {'query': 'what is  tinea', 'id': 671988},
#  {'query': 'what company originated java?', 'id': 599608},
#  {'query': 'olive oil negative health effects', 'id': 468441},
#  {'query': 'my allergies are kicking in and im pregnant what can i take',
#   'id': 460780},
#  {'query': 'diseases caused by bacillus cereus', 'id': 152424},
#  {'query': 'what causes thin skin as you age', 'id': 1164625},
#  {'query': 'lumbar puncture medical definition', 'id': 443533},
#  {'query': 'what bills has donald trump signed into law', 'id': 578859},
#  {'query': 'garnett ks population', 'id': 193300},
#  {'query': 'the definition bid rent', 'id': 515082},
#  {'query': 'phone number for infoscout', 'id': 474634},
#  {'query': 'minimum soldier requirements', 'id': 454632},
#  {'query': 'what causes thinning of the retina', 'id': 1164624},
#  {'query': 'how long does it take for baby fish eggs to hatch', 'id': 253515},
#  {'query': 'what caused castleman disease', 'id': 584067},
#  {'query': 'what are cabinets made of', 'id': 555969},
#  {'query': 'google pacific time', 'id': 195984},
#  {'query': 'what causes thyroid to enlarge', 'id': 1164623},
#  {'query': 'what is flagella', 'id': 747654},
#  {'query': 'phrase mutually exclusive meaning', 'id': 475031},
#  {'query': 'average range of heart rate for adolescents', 'id': 41348},
#  {'query': 'what age do kids need to be to go to dentist', 'id': 550793},
#  {'query': 'name origin of belcher', 'id': 461890},
#  {'query': 'what does wreath mean', 'id': 655283},
#  {'query': 'gestation period for hares', 'id': 194677},
#  {'query': 'is perrigrine falcon extinct', 'id': 420756},
#  {'query': 'what are hilton hotels', 'id': 559993},
#  {'query': 'what is dicyclomine used for', 'id': 739314},
#  {'query': 'what is a medical gas', 'id': 690493},
#  {'query': 'what channel is american horror story on', 'id': 594535},
#  {'query': 'what causes tongue deviation', 'id': 1164621},
#  {'query': 'what county is staten island, ny in?', 'id': 613227},
#  {'query': 'hsn code for automobiles parts in india', 'id': 389122},
#  {'query': 'is chromium safe browser', 'id': 406353},
#  {'query': 'what does an advertising and marketing manager do', 'id': 631638},
#  {'query': 'biblical definition of equity', 'id': 52602},
#  {'query': 'what are the characteristics of sociopath', 'id': 568157},
#  {'query': 'what causes tonsils to turn black and die', 'id': 1164620},
#  {'query': 'if you are driving slow on interstate which lane do u use',
#   'id': 392035},
#  {'query': 'what are the two major functions of a dialyzer?', 'id': 575138},
#  {'query': 'what does freight collect means', 'id': 637889},
#  {'query': 'what date was the virginia convention', 'id': 616417},
#  {'query': 'what county is pomona ny', 'id': 611475},
#  {'query': 'what county is dillsburg pa', 'id': 605145},
#  {'query': 'what food contains bifidobacterium', 'id': 660255},
#  {'query': 'us bank hours glenway', 'id': 533485},
#  {'query': 'what color is charcoal', 'id': 597793},
#  {'query': 'what is gist', 'id': 751080},
#  {'query': 'what is an assent form', 'id': 712435},
#  {'query': 'whale ornament', 'id': 548732},
#  {'query': 'average cost of radiation treatments', 'id': 34316},
#  {'query': 'cost of an echocardiogram', 'id': 102444},
#  {'query': 'what causes u joints to break', 'id': 1164616},
#  {'query': 'what is an.fha loan', 'id': 717686},
#  {'query': "translate c'est la vie to english", 'id': 523867},
#  {'query': 'cost of home theater installation', 'id': 104600},
#  {'query': 'what does the name kai mean', 'id': 650957},
#  {'query': 'buddhism animals symbolism', 'id': 56847},
#  {'query': 'define local color', 'id': 123452},
#  {'query': 'what does deep tendon reflexes 2+ mean', 'id': 635698},
#  {'query': 'average salary uk 1970', 'id': 43659},
#  {'query': 'what causes ulcers on dogs eyes', 'id': 1164614},
#  {'query': 'what is a christian worldview', 'id': 677376},
#  {'query': 'jeffrey preston net worth', 'id': 433037},
#  {'query': 'define standard deviation for a group', 'id': 127409},
#  {'query': 'what is an individual taxpayer identification number',
#   'id': 715216},
#  {'query': 'what is artificial respiration known as', 'id': 719970},
#  {'query': "calories in mike's margarita classic", 'id': 60569},
#  {'query': 'what is definition of management change', 'id': 738170},
#  {'query': 'legal definition of mediation', 'id': 438897},
#  {'query': 'what body system is the skin a part of', 'id': 579518},
#  {'query': 'what doctor treat ptsd?', 'id': 627297},
#  {'query': 'what county is forney', 'id': 606003},
#  {'query': 'how many people died in dunkirk', 'id': 292180},
#  {'query': 'us congress salary', 'id': 533619},
#  {'query': 'difference between horse and pony', 'id': 147558},
#  {'query': 'population lumberton texas', 'id': 477204},
#  {'query': "what do you call it when it's snowing and lightning",
#   'id': 626245},
#  {'query': 'meatloaf calories homemade', 'id': 450766},
#  {'query': 'what is asio direct monitoring', 'id': 720167},
#  {'query': 'meaning of amalgamated', 'id': 1173756},
#  {'query': 'what is dermalone ointment used for', 'id': 738731},
#  {'query': 'meaning of name nastasia', 'id': 448634},
#  {'query': 'is a productive cough good', 'id': 400699},
#  {'query': 'is soccer a large sport in canada', 'id': 424037},
#  {'query': 'is fosamax a bisphosphonate', 'id': 410490},
#  {'query': 'trump hotel las vegas is there a resort fee', 'id': 525060},
#  {'query': 'vitamin d refill', 'id': 537804},
#  {'query': 'what application opens .mdb files?', 'id': 554195},
#  {'query': 'what causes shaking when braking', 'id': 591523},
#  {'query': 'how much blood does an average person have', 'id': 302650},
#  {'query': 'bipolar medication most commonly prescribed', 'id': 54038},
#  {'query': 'symptoms stds in women', 'id': 509174},
#  {'query': 'what does i.t pan mean', 'id': 627862},
#  {'query': 'is herceptin considered chemotherapy', 'id': 412168},
#  {'query': 'how long does it take to pass out upside down', 'id': 257796},
#  {'query': 'what is a informative essay', 'id': 687552},
#  {'query': 'meaning of the name rubaiyat', 'id': 450088},
#  {'query': 'what color does copper streak', 'id': 597463},
#  {'query': 'how many oz gallon', 'id': 291387},
#  {'query': 'does the skin hurt on the outside of your leg with blood clots?',
#   'id': 172936},
#  {'query': 'what is bdc', 'id': 722806},
#  {'query': 'what dose ~ mean', 'id': 655766},
#  {'query': 'what causes facial skin to darken', 'id': 587789},
#  {'query': 'what county is george iowa in', 'id': 606412},
#  {'query': 'what is a composite chemical', 'id': 678551},
#  {'query': 'alcohol urine test how long in system', 'id': 15297},
#  {'query': 'what causes dwarfism in humans', 'id': 587387},
#  {'query': 'what is a compost toilet', 'id': 678570},
#  {'query': 'how long does it take for a severe sunburn to heal', 'id': 253236},
#  {'query': 'symptoms of blood clot in bend of leg', 'id': 507179},
#  {'query': 'what does the western meadowlark eat', 'id': 653401},
#  {'query': 'leading causes of death for children in the us', 'id': 438312},
#  {'query': 'average bail of hay per acre in michigan', 'id': 31292},
#  {'query': 'define wool', 'id': 129207},
#  {'query': 'what are synthetic drugs', 'id': 566690},
#  {'query': 'how many calories does banana contain', 'id': 276526},
#  {'query': 'what causes white calcium in ear', 'id': 1164603},
#  {'query': 'how much is judo class', 'id': 322399},
#  {'query': 'what is hpw for sugar gliders', 'id': 755940},
#  {'query': 'linea alba definition', 'id': 440285},
#  {'query': 'jamocha shake calories', 'id': 432744},
#  {'query': 'idea definition of intellectual disability', 'id': 390926},
#  {'query': 'what enzymes are needed to break down fat', 'id': 657572},
#  {'query': 'what is a ear blockage', 'id': 682423},
#  {'query': 'what is epididymitis', 'id': 744376},
#  {'query': 'what county is lincoln park nj', 'id': 608614},
#  {'query': 'what are education credit limits', 'id': 558104},
#  {'query': 'most average height of a newborn', 'id': 456376},
#  {'query': 'normal cost to have a lawn redone', 'id': 465313},
#  {'query': 'what is a wall fistula', 'id': 705857},
#  {'query': 'define: teetotaler', 'id': 129798},
#  {'query': 'what county is willard nm in?', 'id': 614649},
#  {'query': 'what is google pinyin input', 'id': 752156},
#  {'query': "what causes you to get the pink eye and it's systems",
#   'id': 1164600},
#  {'query': 'mouth hurts when i swallow and tongue presses on roof of mouth',
#   'id': 459920},
#  {'query': 'is sodium carbonate soluble', 'id': 424122},
#  {'query': 'bumfuzzled definition', 'id': 57109},
#  {'query': 'what is caps mean', 'id': 727609},
#  {'query': 'what can you use a deferred prosecution on', 'id': 6937},
#  {'query': 'meaning of seeing a wild turkey', 'id': 449158},
#  {'query': 'what health problems are associated with childhood obesity?',
#   'id': 668254},
#  {'query': 'what is a deviated septum', 'id': 681057},
#  {'query': 'is diabetes genetic', 'id': 408170},
#  {'query': 'what county is beech island sc in', 'id': 602970},
#  {'query': 'what is a synapse in writing', 'id': 702490},
#  {'query': 'what causes your leg to spasms', 'id': 1164598},
#  {'query': 'is yahoo a search engine?', 'id': 431733},
#  {'query': 'what is chipotle chili powder', 'id': 730205},
#  {'query': 'what county is seymour wi in?', 'id': 612613},
#  {'query': 'how many carbs does a baked potato have', 'id': 278451},
#  {'query': 'vgenx dividend', 'id': 536774},
#  {'query': 'what is feline leukemia in kittens', 'id': 746799},
#  {'query': 'what is intrapreneurship', 'id': 760141},
#  {'query': 'pari name origin', 'id': 471791},
#  {'query': 'institution definition', 'id': 396573},
#  {'query': 'explain shotgun choke tubes', 'id': 183769},
#  {'query': 'what abiotic factors affect climate', 'id': 549307},
#  {'query': 'largest cement companies', 'id': 436113},
#  {'query': 'standalone meaning in english', 'id': 502288},
#  {'query': 'engine stall causes', 'id': 180547},
#  {'query': 'what is brioche bread', 'id': 725934},
#  {'query': 'is mandelate a salt', 'id': 417200},
#  {'query': 'what is crdp', 'id': 735698},
#  {'query': 'how early to give hepatitis b vaccine', 'id': 229125},
#  {'query': 'what colors do plant pigments reflect', 'id': 598869},
#  {'query': 'average cost of rent in san jose california?', 'id': 34364},
#  {'query': 'how do anthropologists view culture', 'id': 216395},
#  {'query': 'how to sync computer to ps3', 'id': 382076},
#  {'query': 'what is genoese', 'id': 750548},
#  {'query': 'what cell does prolactin connect to', 'id': 1164593},
#  {'query': 'what is a hemispherical combustion chamber?', 'id': 686671},
#  ...]
